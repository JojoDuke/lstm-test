# %% [markdown]
# **LSTM without Dropout**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split # Import train_test_split

# Load the dataset
data = pd.read_csv('AU.csv')  # Replace 'MSFT-1.csv' with your file
data = data['Close'].values.reshape(-1, 1)


# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the training data
def create_dataset(dataset, time_step=1):
    X, Y = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        X.append(a)
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 60  # Adjust as needed
X, y = create_dataset(scaled_data, time_step)

# Split the data into train and test sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input to be [samples, time steps, features] for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Define the LSTM model without dropout
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=1)  # Adjust epochs and batch size

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Invert predictions to original scale
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate performance metrics
def calculate_metrics(actual, predicted):
    return {
        'R2 Score': r2_score(actual, predicted),
        'MAE': mean_absolute_error(actual, predicted),
        'MSE': mean_squared_error(actual, predicted),
        'RMSE': np.sqrt(mean_squared_error(actual, predicted))
    }

metrics = calculate_metrics(y_test, test_predict)

# Display metrics in a table
metrics_df = pd.DataFrame([metrics], index=['LSTM without Dropout'])
print(metrics_df)

# Plot the results
plt.figure(figsize=(12, 6))

# Plot the entire actual data
plt.plot(data, label='Actual Prices', color='blue')

# Plot test predictions
plt.plot(np.arange(len(train_predict) + time_step, len(train_predict) + time_step + len(test_predict)),
         test_predict, label='Test Predictions', color='red')

plt.title('Stock Price Prediction with LSTM Without Dropout')
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# /usr/local/python/3.10.13/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.0264
# Epoch 2/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 9.7026e-04
# Epoch 3/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 8.2394e-04
# Epoch 4/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 7.3335e-04
# Epoch 5/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 6.1793e-04
# Epoch 6/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 5.9320e-04
# Epoch 7/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 4.8770e-04
# Epoch 8/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 4.2399e-04
# Epoch 9/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 3.7732e-04
# Epoch 10/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 3.4344e-04
# Epoch 11/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 3.3788e-04
# Epoch 12/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 3.0884e-04
# Epoch 13/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 2.9850e-04
# Epoch 14/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 3.2192e-04
# Epoch 15/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.4542e-04
# Epoch 16/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 2.7300e-04
# Epoch 17/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.5565e-04
# Epoch 18/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.2948e-04
# Epoch 19/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 2.6489e-04
# Epoch 20/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3480e-04
# Epoch 21/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 2.5038e-04
# Epoch 22/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.2382e-04
# Epoch 23/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3546e-04
# Epoch 24/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.5245e-04
# Epoch 25/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.1628e-04
# Epoch 26/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 2.8088e-04
# Epoch 27/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3652e-04
# Epoch 28/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 2.3662e-04
# Epoch 29/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 2.5620e-04
# Epoch 30/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 2.2973e-04
# Epoch 31/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3863e-04
# Epoch 32/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 2.3744e-04
# Epoch 33/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.5710e-04
# Epoch 34/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 2.1948e-04
# Epoch 35/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.4451e-04
# Epoch 36/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.2162e-04
# Epoch 37/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3222e-04
# Epoch 38/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.7960e-04
# Epoch 39/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.0996e-04
# Epoch 40/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3267e-04
# Epoch 41/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.1036e-04
# Epoch 42/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.5260e-04
# Epoch 43/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3475e-04
# Epoch 44/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 2.3364e-04
# Epoch 45/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 2.1279e-04
# Epoch 46/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3935e-04
# Epoch 47/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.3249e-04
# Epoch 48/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.5905e-04
# Epoch 49/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.4261e-04
# Epoch 50/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 2.3070e-04
# Epoch 51/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 2.4806e-04
# Epoch 52/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss:
150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.1368e-04
# Epoch 148/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.1053e-04
# Epoch 149/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.0007e-04
# Epoch 150/150
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 2.1251e-04
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#                       R2 Score       MAE       MSE      RMSE
# LSTM without Dropout  0.971458  0.493033  0.472092  0.687089

# %% [markdown]
# **LSTM with Bernoulli Dropout**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split

# Load the dataset
data = pd.read_csv('MSFT-1.csv') # Replace 'MSFT-1.csv' with your file
data = data['Close'].values.reshape(-1, 1)

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the training data
def create_dataset(dataset, time_step=1):
    X, Y = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        X.append(a)
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 60  # Adjust as needed
X, y = create_dataset(scaled_data, time_step)

# Split the data into train and test sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input to be [samples, time steps, features] for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Define the LSTM model with Bernoulli dropout
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))  # Bernoulli dropout
model.add(LSTM(units=50))
model.add(Dropout(0.2))  # Bernoulli dropout
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=1)  # Adjust epochs and batch size

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Invert predictions to original scale
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate performance metrics
def calculate_metrics(actual, predicted):
    return {
        'R2 Score': r2_score(actual, predicted),
        'MAE': mean_absolute_error(actual, predicted),
        'MSE': mean_squared_error(actual, predicted),
        'RMSE': np.sqrt(mean_squared_error(actual, predicted))
    }

metrics = calculate_metrics(y_test, test_predict)

# Display metrics in a table
metrics_df = pd.DataFrame([metrics], index=['LSTM with Bernoulli Dropout'])
print(metrics_df)
# Plot the results
plt.figure(figsize=(12, 6))

# Plot the entire actual data
plt.plot(data, label='Actual Prices', color='blue')

# Plot test predictions
plt.plot(np.arange(len(train_predict) + time_step, len(train_predict) + time_step + len(test_predict)),
         test_predict, label='Test Predictions', color='red')

plt.title('Stock Price Prediction with LSTM With Bernoulli Dropout')
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# /usr/local/python/3.10.13/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - loss: 5.1263e-04
# Epoch 2/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 4.2089e-05
# Epoch 3/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 3.3361e-05
# Epoch 4/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 2.8537e-05
# Epoch 5/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.3973e-05
# Epoch 6/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 2.2742e-05
# Epoch 7/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.1747e-05
# Epoch 8/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.0338e-05
# Epoch 9/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 1.9564e-05
# Epoch 10/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 1.9592e-05
# Epoch 11/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 1.8859e-05
# Epoch 12/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.1695e-05
# Epoch 13/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 2.1592e-05
# Epoch 14/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.9852e-05
# Epoch 15/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 1.9464e-05
# Epoch 16/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 1.7639e-05
# Epoch 17/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 1.7281e-05
# Epoch 18/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.0380e-05
# Epoch 19/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 1.9771e-05
# Epoch 20/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.8183e-05
# Epoch 21/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 1.9565e-05
# Epoch 22/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.6765e-05
# Epoch 23/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.8530e-05
# Epoch 24/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.8332e-05
# Epoch 25/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 1.8317e-05
# Epoch 26/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.8546e-05
# Epoch 27/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.7321e-05
# Epoch 28/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.7782e-05
# Epoch 29/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.8078e-05
# Epoch 30/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 1.8608e-05
# Epoch 31/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.8937e-05
# Epoch 32/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.8120e-05
# Epoch 33/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 1.7924e-05
# Epoch 34/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.5779e-05
# Epoch 35/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.7722e-05
# Epoch 36/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.5762e-05
# Epoch 37/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.7988e-05
# Epoch 38/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 1.6258e-05
# Epoch 39/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.7720e-05
# Epoch 40/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 1.7628e-05
# Epoch 41/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 1.8038e-05
# Epoch 42/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1
150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 1.4585e-05
# Epoch 139/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 1.3580e-05
# Epoch 140/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 1.3473e-05
# Epoch 141/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 1.3716e-05
# Epoch 142/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 1.4619e-05
# Epoch 143/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 1.3733e-05
# Epoch 144/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 1.4536e-05
# Epoch 145/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 1.3371e-05
# Epoch 146/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 1.4541e-05
# Epoch 147/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 1.3985e-05
# Epoch 148/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 1.3864e-05
# Epoch 149/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 1.4539e-05
# Epoch 150/150
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 1.4461e-05
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#                              R2 Score       MAE        MSE      RMSE
# LSTM with Bernoulli Dropout  0.994533  3.323797  38.397766  6.196593

# %% [markdown]
# **LSTM with Binomial Dropout**

# %% [markdown]
# **x: The input tensor (a multi-dimensional array), representing the activations (outputs) of neurons in a neural network layer.**
#
# **n: The number of trials, representing how many times each neuron will be tested for dropout.**
#
# **p: The dropout probability, which determines the likelihood that a neuron will be dropped in each trial.**
#
# **np= Expected number of trials for a neuron to be dropped out after trials**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, Lambda
import tensorflow as tf

# Load and preprocess the dataset
data = pd.read_csv('MSFT-1.csv')
data = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the training and testing data
def create_dataset(dataset, time_step=1):
    X, Y = [], []
    for i in range(len(dataset) - time_step):
        X.append(dataset[i:(i + time_step), 0])
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Define binomial dropout function
def binomial_dropout(x, n=20, p=0.2):
    mask = tf.zeros_like(x)  # Initialize the mask with zeros
    for _ in range(n):
        dropout_mask = tf.cast(tf.random.uniform(shape=tf.shape(x)) < p, dtype=tf.float32)
        mask += dropout_mask  # Accumulate the dropout mask
    mask = tf.cast(mask <= n*p, dtype=tf.float32)  # Apply binomial condition
    return x * mask

# Create LSTM model with Binomial Dropout
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], 1), return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Lambda(lambda x: binomial_dropout(x, n=20, p=0.2)))  # Apply binomial dropout
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Invert predictions to original scale
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate performance metrics
def calculate_metrics(actual, predicted):
    return {
        'R2 Score': r2_score(actual, predicted),
        'MAE': mean_absolute_error(actual, predicted),
        'MSE': mean_squared_error(actual, predicted),
        'RMSE': np.sqrt(mean_squared_error(actual, predicted))
    }

metrics = calculate_metrics(y_test, test_predict)

# Display metrics in a table
metrics_df = pd.DataFrame([metrics], index=['LSTM with binomial Dropout'])
print(metrics_df)



# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(scaler.inverse_transform(scaled_data), label='Actual Prices', color='blue')

# Shift train predictions for plotting
train_predict_plot = np.empty_like(scaled_data)
train_predict_plot[:, :] = np.nan
train_predict_plot[time_step:len(train_predict) + time_step, :] = train_predict

# Shift test predictions for plotting
test_predict_plot = np.empty_like(scaled_data)
test_predict_plot[:, :] = np.nan
# Correct the starting index for the test predictions slice
test_predict_plot[len(train_predict) + time_step:len(train_predict) + time_step + len(test_predict), :] = test_predict

# Plot the predictions
plt.plot(test_predict_plot, label='Test Predictions', color='red')

plt.title('Stock Price Prediction with LSTM and Binomial Dropout')
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# /usr/local/python/3.10.13/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 6.0512e-04
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 5.9720e-05
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 4.2257e-05
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 3.8294e-05
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 3.3625e-05
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 3.2805e-05
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 3.2881e-05
# Epoch 8/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 3.4801e-05
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 2.9605e-05
# Epoch 10/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 3.3124e-05
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 3.1558e-05
# Epoch 12/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 3.0262e-05
# Epoch 13/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 3.1149e-05
# Epoch 14/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 3.3182e-05
# Epoch 15/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.8831e-05
# Epoch 16/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.9344e-05
# Epoch 17/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.9392e-05
# Epoch 18/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.8691e-05
# Epoch 19/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.9634e-05
# Epoch 20/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 3.0887e-05
# Epoch 21/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.9711e-05
# Epoch 22/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 3.0214e-05
# Epoch 23/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.9044e-05
# Epoch 24/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 3.1555e-05
# Epoch 25/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.8840e-05
# Epoch 26/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.9159e-05
# Epoch 27/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.7923e-05
# Epoch 28/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.9441e-05
# Epoch 29/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 2.6207e-05
# Epoch 30/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.7922e-05
# Epoch 31/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.5861e-05
# Epoch 32/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.7533e-05
# Epoch 33/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.7877e-05
# Epoch 34/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.7927e-05
# Epoch 35/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.8595e-05
# Epoch 36/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.8157e-05
# Epoch 37/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.7941e-05
# Epoch 38/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.6844e-05
# Epoch 39/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.6520e-05
# Epoch 40/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.5541e-05
# Epoch 41/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 2.6931e-05
# Epoch 42/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.5863e-05
# Epoch 43/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.6981e-05
# Epoch 44/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.6985e-05
# Epoch 45/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.7700e-05
# Epoch 46/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.6290e-05
# Epoch 47/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.7657e-05
# Epoch 48/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 2.7483e-05
# Epoch 49/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 2.6249e-05
# Epoch 50/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.7399e-05
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#                             R2 Score        MAE         MSE       RMSE
# LSTM with binomial Dropout  0.963679  10.185485  255.550998  15.985963

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, Lambda
import tensorflow as tf

# Load and preprocess the dataset
data = pd.read_csv('MSFT-1.csv')
data = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the training and testing data
def create_dataset(dataset, time_step=1):
    X, Y = [], []
    for i in range(len(dataset) - time_step):
        X.append(dataset[i:(i + time_step), 0])
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Define binomial dropout function
def binomial_dropout(x, n=4, p=0.2):
    mask = tf.zeros_like(x)  # Initialize the mask with zeros
    for _ in range(n):
        dropout_mask = tf.cast(tf.random.uniform(shape=tf.shape(x)) < p, dtype=tf.float32)
        mask += dropout_mask  # Accumulate the dropout mask
    mask = tf.cast(mask < n*p, dtype=tf.float32)  # Apply binomial condition
    return x * mask

# Create LSTM model with Binomial Dropout
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], 1), return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Lambda(lambda x: binomial_dropout(x, n=5, p=0.2)))  # Apply binomial dropout
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Invert predictions to original scale
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate performance metrics
def calculate_metrics(actual, predicted):
    return {
        'R2 Score': r2_score(actual, predicted),
        'MAE': mean_absolute_error(actual, predicted),
        'MSE': mean_squared_error(actual, predicted),
        'RMSE': np.sqrt(mean_squared_error(actual, predicted))
    }

metrics = calculate_metrics(y_test, test_predict)

# Display metrics in a table
metrics_df = pd.DataFrame([metrics], index=['LSTM with binomial Dropout'])
print(metrics_df)


# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(scaler.inverse_transform(scaled_data), label='Actual Prices', color='blue')

# Shift train predictions for plotting
train_predict_plot = np.empty_like(scaled_data)
train_predict_plot[:, :] = np.nan
train_predict_plot[time_step:len(train_predict) + time_step, :] = train_predict

# Shift test predictions for plotting
test_predict_plot = np.empty_like(scaled_data)
test_predict_plot[:, :] = np.nan
# Correct the starting index for the test predictions slice
test_predict_plot[len(train_predict) + time_step:len(train_predict) + time_step + len(test_predict), :] = test_predict

# Plot the predictions
plt.plot(test_predict_plot, label='Test Predictions', color='red')

plt.title('Stock Price Prediction with LSTM and Binomial Dropout')
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **N=50, P=0.2**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras import backend as K # Import the Keras backend
# Load data
data = pd.read_csv('AU.csv')

# Preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data['Close'].values.reshape(-1, 1))

# Split data into training and testing sets
train_size = int(len(scaled_data) * 0.8)
test_size = len(scaled_data) - train_size
train_data, test_data = scaled_data[0:train_size, :], scaled_data[train_size:len(scaled_data), :]

# Create a dataset for LSTM
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 60  # Adjust look_back period
trainX, trainY = create_dataset(train_data, look_back)
testX, testY = create_dataset(test_data, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# Custom Binomial Dropout Layer
class BinomialDropout(Dropout):
    def __init__(self, rate, n, **kwargs):
        super(BinomialDropout, self).__init__(rate, **kwargs)
        self.n = n

    def call(self, inputs, training=None):
        if training: # Use 'if training:' to conditionally apply dropout during training
            binomial_mask = np.random.binomial(1, self.rate, size=(self.n,))
            return inputs * binomial_mask
        return inputs # Return inputs unchanged during inference

# Create and train the LSTM model with Binomial Dropout
model_binomial = Sequential()
model_binomial.add(LSTM(50, return_sequences=True, input_shape=(look_back, 1)))
model_binomial.add(BinomialDropout(rate=0.2, n=50))
model_binomial.add(LSTM(50, return_sequences=False))
model_binomial.add(BinomialDropout(rate=0.2, n=50))
model_binomial.add(Dense(1))

model_binomial.compile(optimizer='adam', loss='mean_squared_error')
model_binomial.fit(trainX, trainY, epochs=100, batch_size=32)

# Make predictions on test data
train_predict = model_binomial.predict(trainX)
test_predict = model_binomial.predict(testX)
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
testY = scaler.inverse_transform(testY.reshape(-1, 1))




# Calculate performance metrics
def calculate_metrics(actual, predicted):
    # Ensure actual and predicted have the same number of samples
    min_samples = min(len(actual), len(predicted))
    actual = actual[:min_samples]
    predicted = predicted[:min_samples]

    return {
        'R2 Score': r2_score(actual, predicted),
        'MAE': mean_absolute_error(actual, predicted),
        'MSE': mean_squared_error(actual, predicted),
        'RMSE': np.sqrt(mean_squared_error(actual, predicted))
    }


metrics = calculate_metrics(y_test, test_predict)

# Display metrics in a table
metrics_df = pd.DataFrame([metrics], index=['LSTM with Binomial Dropout'])
print(metrics_df)

# Plot the results
plt.figure(figsize=(12, 6))

# Plot the entire actual data
plt.plot(data['Close'].values, label='Actual Prices', color='blue')

# Plot test predictions
plt.plot(np.arange(len(train_predict) + look_back, len(train_predict) + look_back + len(test_predict)),
         test_predict, label='Test Predictions', color='red')

plt.title('Stock Price Prediction with LSTM and Binomial Dropout')
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# /usr/local/python/3.10.13/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.0568
# Epoch 2/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0021
# Epoch 3/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0018
# Epoch 4/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0014
# Epoch 5/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0012
# Epoch 6/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0011
# Epoch 7/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 8.7404e-04
# Epoch 8/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 7.8585e-04
# Epoch 9/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: